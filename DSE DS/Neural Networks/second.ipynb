# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Load dataset
df = pd.read_csv("dataset.csv")

# Select features and target
X = df[['year', 'laps', 'continent', 'circuit']]
y = df['team']

# Encode categorical features
X = pd.get_dummies(X, columns=['continent', 'circuit'])

# Encode target (team)
team_encoder = LabelEncoder()
y = team_encoder.fit_transform(y)

# Scale numeric features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# Build neural network
model = Sequential([
    Dense(128, activation='sigmoid', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='sigmoid'),
    Dropout(0.2),
    Dense(len(set(y)), activation='softmax')  # multi-class classification
])

# Compile
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# Train
history = model.fit(
    X_train, y_train, 
    epochs=30, 
    batch_size=16, 
    validation_split=0.2,
    verbose=1
)

# Evaluate
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy - {accuracy:.2f}")

# Example prediction
sample = X_test[0].reshape(1, -1)
pred_class = model.predict(sample).argmax()
print("Predicted team - ", team_encoder.inverse_transform([pred_class])[0])
# Out:
# c:\Users\me\test-practice-others\.venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.1575 - loss: 3.6395 - val_accuracy: 0.2459 - val_loss: 3.2462
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2219 - loss: 3.2526 - val_accuracy: 0.2459 - val_loss: 3.2175
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.2110 - loss: 3.1963 - val_accuracy: 0.2459 - val_loss: 3.2204
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2137 - loss: 3.1841 - val_accuracy: 0.2459 - val_loss: 3.2364
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2178 - loss: 3.1462 - val_accuracy: 0.2459 - val_loss: 3.2248
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2260 - loss: 3.1178 - val_accuracy: 0.2459 - val_loss: 3.2221
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2342 - loss: 3.0819 - val_accuracy: 0.2568 - val_loss: 3.2153
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2466 - loss: 3.0608 - val_accuracy: 0.2568 - val_loss: 3.1868
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2301 - loss: 3.0304 - val_accuracy: 0.2842 - val_loss: 3.1784
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2411 - loss: 2.9800 - val_accuracy: 0.2842 - val_loss: 3.1568
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2329 - loss: 2.9484 - val_accuracy: 0.2787 - val_loss: 3.1495
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2466 - loss: 2.8862 - val_accuracy: 0.2951 - val_loss: 3.1269
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2479 - loss: 2.8527 - val_accuracy: 0.2787 - val_loss: 3.1105
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2603 - loss: 2.8241 - val_accuracy: 0.2842 - val_loss: 3.1002
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2671 - loss: 2.7882 - val_accuracy: 0.2896 - val_loss: 3.0870
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2795 - loss: 2.7466 - val_accuracy: 0.2951 - val_loss: 3.0583
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2795 - loss: 2.6921 - val_accuracy: 0.3005 - val_loss: 3.0754
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2836 - loss: 2.6649 - val_accuracy: 0.3005 - val_loss: 3.0546
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2767 - loss: 2.6458 - val_accuracy: 0.3060 - val_loss: 3.0385
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2890 - loss: 2.6466 - val_accuracy: 0.3060 - val_loss: 3.0405
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2959 - loss: 2.5836 - val_accuracy: 0.2951 - val_loss: 3.0272
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2836 - loss: 2.5945 - val_accuracy: 0.2842 - val_loss: 3.0227
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2836 - loss: 2.5786 - val_accuracy: 0.3115 - val_loss: 3.0242
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2959 - loss: 2.5229 - val_accuracy: 0.3115 - val_loss: 3.0194
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2932 - loss: 2.5169 - val_accuracy: 0.3005 - val_loss: 3.0072
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2863 - loss: 2.5318 - val_accuracy: 0.2896 - val_loss: 3.0077
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2945 - loss: 2.4802 - val_accuracy: 0.3115 - val_loss: 2.9961
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2836 - loss: 2.4659 - val_accuracy: 0.2951 - val_loss: 2.9852
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3014 - loss: 2.4377 - val_accuracy: 0.2896 - val_loss: 2.9847
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3082 - loss: 2.4330 - val_accuracy: 0.3115 - val_loss: 2.9880
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2402 - loss: 2.9218
# Test Accuracy - 0.24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Predicted team -  Ferrari

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("dataset.csv")

# Filter for races since 2000 and count wins per team
team_wins_2000 = df[df['year'] >= 2015]['team'].value_counts().reset_index()
team_wins_2000.columns = ['team', 'wins']
print(team_wins_2000)
# Out:
#                           team  wins
# 0                     Mercedes   101
# 1   Red Bull Racing Honda RBPT    30
# 2                      Ferrari    27
# 3         Red Bull Racing RBPT    17
# 4        Red Bull Racing Honda    16
# 5                      McLaren    11
# 6    Red Bull Racing TAG Heuer     9
# 7             McLaren Mercedes     7
# 8              Red Bull Racing     2
# 9               Alpine Renault     1
# 10            AlphaTauri Honda     1
# 11   Racing Point BWT Mercedes     1
